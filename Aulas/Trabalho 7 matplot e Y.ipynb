# %%
import numpy as np
import math
def numero(n=10):
    lista=[]
    i=0
    y_i=0
    while i<=n-1:
        x_1=np.random.randint(1,7)
        #print('x_1 =',x_1)
        x_2=np.random.randint(1,7)
        #print('x_2 =',x_2)
        y_i=+x_1 +x_2 
        lista.append(y_i)
        #print('y =',y_i)
        i=i+1
    arr=np.array(lista)
    #Y
    a=sum(arr) ; print("Y:",a)
    #media
    media=a/n ; print("Media:",media)
    #desvio
    desvio=sum((arr[0:n]-media)**2)/n ; print("Desvio:",desvio)
    print(arr)
numero(10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-5d9f56fc9c44> in <module>
#       2 f = open('trajetoria.dat','r+')
#       3 fb=f.read().splitlines()
# ----> 4 fb.split(14)
#       5
#       6
#
# AttributeError: 'list' object has no attribute 'split'

# %%
import matplotlib.pyplot as plt
import numpy as np
f = open('trajetoria.dat','r+')
lista=f.read().splitlines()
i=0
listt=[]
listx=[]
listy=[]
while i<=(len(lista)-2):
    listt.append(lista[i].split()[0])
    listx.append(lista[i].split()[1])
    listy.append(lista[i].split()[2])
    i=i+1
arrt=np.array(listt)
arrx=np.array(listx)
arry=np.array(listy)
t=arrt.astype(np.float).tolist()
x=arrx.astype(np.float).tolist()
y=arry.astype(np.float).tolist()

plt.plot(x,t) ;plt.show()
plt.plot(y,t) ;plt.show()
plt.plot(x,y) ;plt.show()

# %%
import numpy as np
def numero(n):
    lista=[]
    i=0
    y_i=0
    while i<=n-1:
        x_1=np.random.randint(1,7)
        #print('x_1 =',x_1)
        x_2=np.random.randint(1,7)
        #print('x_2 =',x_2)
        y_i=+x_1 +x_2 
        lista.append(y_i) 
        print('y =',y_i)
        i=i+1
    arr=np.array(lista)
    return(arr)
def media(n):
    arr=numero(n)
    media=sum(arr)/n
    return(media,arr)
def desvio(n):
    m,a=media(n)
    #arr=numero(n)
    #print('arr',a)
    arr2=(a-m)**2
    #print('arr2',arr2)
    desvio=np.sqrt(sum(arr2)/(n))
    return(desvio,m)
media(3)
# Out:
# y = 12
# y = 7
# y = 6
# (8.333333333333334, array([12,  7,  6]))
